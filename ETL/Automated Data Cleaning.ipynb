# %%
# install required packages

#!pip install --upgrade pip
#!pip install loguru
#!pip install py-AutoClean

# %%
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
# Dataset - https://www.kaggle.com/datasets/shivamb/amazon-prime-movies-and-tv-shows
# load the dataset
dataset = pd.read_csv('amazon_primevideo.csv')
print(dataset.columns)
dataset.isna().sum()
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')
# show_id            0
# type               0
# title              0
# director        2082
# cast            1233
# country         8996
# date_added      9513
# release_year       0
# rating           337
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
dataset = dataset[['type', 'title', 'director', 'cast', 'release_year', 'listed_in', 'description']]
dataset
# Out:
#          type                    title         director  \
# 0       Movie      The Grand Seduction     Don McKellar
# 1       Movie     Take Care Good Night     Girish Joshi
# 2       Movie     Secrets of Deception      Josh Webber
# 3       Movie       Pink: Staying True   Sonia Anderson
# 4       Movie            Monster Maker     Giles Foster
# ...       ...                      ...              ...
# 9663    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664  TV Show            Planet Patrol              NaN
# 9665    Movie                  Outpost     Steve Barker
# 9666  TV Show  Maradona: Blessed Dream              NaN
# 9667    Movie              Harry Brown    Daniel Barber
#
#                                                    cast  release_year  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          2014
# 1      Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar          2018
# 2     Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...          2017
# ...

# %%
# check missing values
print("total_rows - ", dataset.shape[0])

dataset.isna().sum()
# Out:
# total_rows -  9668
# type               0
# title              0
# director        2082
# cast            1233
# release_year       0
# listed_in          0
# description        0
# dtype: int64

# %%
dataset = dataset.dropna()
dataset = dataset.reset_index(drop=True)
dataset.isna().sum()
# Out:
# type            0
# title           0
# director        0
# cast            0
# release_year    0
# listed_in       0
# description     0
# dtype: int64

# %%
from AutoClean import AutoClean
pipeline = AutoClean(dataset)
pipeline.output
# Out:
#      show_id     type                    title         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol         Jay Dahl
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream         Jay Dahl
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast               country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent                Canada
# ...
